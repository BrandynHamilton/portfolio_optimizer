# %%
from openbb import obb
import pandas as pd

# %%
obb.user.preferences.output_type="dataframe"

# %%
historical_prices = obb.equity.price.historical("aapl", provider="yfinance")

# %%
historical_prices
# Out:
#                   open        high         low       close    volume  \
# date
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  46638100
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  60750200
# 2023-07-13  190.500000  191.190002  189.779999  190.539993  41342300
# 2023-07-14  190.229996  191.179993  189.630005  190.690002  41573900
# 2023-07-17  191.899994  194.320007  191.809998  193.990005  50520200
# ...                ...         ...         ...         ...       ...
# 2024-07-05  221.649994  226.449997  221.649994  226.339996  60412400
# 2024-07-08  227.089996  227.850006  223.250000  227.820007  59085900
# 2024-07-09  227.929993  229.399994  226.369995  228.679993  48076100
# 2024-07-10  229.300003  233.080002  229.250000  232.979996  62557700
# 2024-07-11  231.311996  232.389999  225.770004  228.323196  35283932
#
#             split_ratio  dividend
# date
# 2023-07-11          0.0       0.0
# 2023-07-12          0.0       0.0
# ...

# %%
# Get list of top high yield dividend etfs - benchmarks
# Get list of dividend stocks - portfolio
